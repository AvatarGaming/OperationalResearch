# %% [markdown]
# # EJERCICIO 03: Estrategias de Publicidad en Marketing
#
# ## Selección de Medios
#
# Los modelos de programación lineal se han utilizado en el campo de la publicidad como una ayuda para la toma de decisiones en la selección de una mezcla de medios efectiva. A veces, la técnica se emplea para asignar un presupuesto fijo o limitado entre varios medios, que pueden incluir comerciales de radio o televisión, anuncios en periódicos, envíos por correo directo, redes sociales, y otros. En otras aplicaciones, el objetivo es la maximización de la exposición de la audiencia. Las restricciones en la mezcla de medios permitida pueden surgir debido a requisitos contractuales, disponibilidad limitada de medios o políticas de la empresa. A continuación, se presenta un ejemplo.
#
# El Club de Juegos "Win Big" promueve viajes de juego desde una gran ciudad del medio oeste a casinos en las Bahamas. El club ha presupuestado hasta $8,000 por semana para publicidad local. El dinero se debe asignar entre cuatro medios promocionales: spots de televisión, anuncios en periódicos, y dos tipos de anuncios de radio. El objetivo de Win Big es llegar a la mayor cantidad posible de audiencia potencial de alto valor a través de los diversos medios. La siguiente tabla presenta el número de potenciales jugadores alcanzados mediante el uso de un anuncio en cada uno de los cuatro medios. También proporciona el costo por anuncio colocado y el número máximo de anuncios que se pueden comprar por semana.
#
# | MEDIO | AUDIENCIA ALCANZADA POR ANUNCIO | COSTO POR ANUNCIO ($) | MÁXIMO DE ANUNCIOS POR SEMANA |
# |-------|----------------------------------|------------------------|-------------------------------|
# | Spot de TV (1 minuto) | 5,000 | 800 | 12 |
# | Periódico diario (anuncio de página completa) | 8,500 | 925 | 5 |
# | Spot de radio (30 segundos, hora pico) | 2,400 | 290 | 25 |
# | Spot de radio (1 minuto, tarde) | 2,800 | 380 | 20 |
#
# Los acuerdos contractuales de Win Big requieren que se coloquen al menos cinco spots de radio cada semana. Para asegurar una campaña promocional de amplio alcance, la gerencia también insiste en que no se gaste más de $1,800 en publicidad de radio cada semana.
#
# Al formular esto como un problema de programación lineal, el primer paso es comprender completamente el problema. A veces, hacer preguntas de "¿qué pasaría sí?" ayudará a entender la situación. En este ejemplo, ¿qué pasaría si se usaran exactamente cinco anuncios de cada tipo? ¿Cuánto costarían los anuncios? ¿A cuántas personas alcanzarían? Sin duda, el uso de una hoja de cálculo para los cálculos puede ayudar con esto, ya que se pueden escribir fórmulas para calcular el costo y el número de personas alcanzadas. Una vez que se entiende la situación, se establecen el objetivo y las restricciones:
#
# ### Objetivo:
# Maximizar el número de personas (audiencia) alcanzadas
#
# ### Restricciones:
# a) No se pueden usar más de 12 anuncios de TV.
# b) No se pueden usar más de 5 anuncios en periódicos.
# c) No se pueden usar más de 25 anuncios de radio de 30 segundos.
# d) No se pueden usar más de 20 anuncios de radio de 1 minuto.
# e) El monto total gastado no puede exceder los $8,000.
# f) El número total de anuncios de radio debe ser al menos 5.
# g) El monto total gastado en anuncios de radio no debe exceder los $1,800.
#
# ### Variables de decisión:
# A continuación, defina las variables de decisión. Las decisiones que se están tomando aquí involucran el número de anuncios de cada tipo a utilizar. Una vez que se conocen, se pueden usar para calcular el monto gastado y el número de personas alcanzadas.
#
# Sea:
# - $X_1$ = número de spots de TV de 1 minuto tomados cada semana
# - $X_2$ = número de anuncios de página completa en el periódico diario tomados cada semana
# - $X_3$ = número de spots de radio de 30 segundos en hora pico tomados cada semana
# - $X_4$ = número de spots de radio de 1 minuto en la tarde tomados cada semana
#
# ### Ecuaciones
# A continuación, usando estas variables, escriba la expresión matemática para el objetivo y las restricciones que se identificaron. Las restricciones de no negatividad también se explicitan.
#
# **Objetivo:**
# Maximizar la cobertura de la audiencia = $5000X_1 + 8500X_2 + 2400X_3 + 2800X_4$
#
# **(Restricciones) Sujeto a:**
# a) $X_1 \leq 12$ (máximo de spots de TV por semana).
# b) $X_2 \leq 5$ (máximo de anuncios en el periódico por semana).
# c) $X_3 \leq 25$ (máximo de spots de radio de 30 segundos por semana).
# d) $X_4 \leq 20$ (máximo de spots de radio de 1 minuto por semana).
# e) $800X_1 + 925X_2 + 290X_3 + 380X_4 \leq 8000$ (presupuesto total no puede exceder los $8000).
# f) $X_3 + X_4 \geq 5$ (al menos 5 anuncios de radio por semana).
# g) $290X_3 + 380X_4 \leq 1800$ (presupuesto en anuncios de radio no puede exceder $1800).
#
# Estas ecuaciones describen el problema de programación lineal para maximizar la audiencia alcanzada dentro de las restricciones presupuestarias y de cantidad de anuncios.

# %% [markdown]
# # 📚 Función del PASO 1: Importar Bibliotecas Necesarias
#
# ## 🧩 Resumen Funcional
#
# El **PASO 1** del script establece los **cimientos tecnológicos** para resolver el problema de optimización publicitaria de "Win Big". Importa bibliotecas esenciales:
#
# | 📦 Biblioteca | 🛠️ Función Principal | 🔗 Relación con el Ejercicio |
# |---------------|----------------------|------------------------------|
# | **PuLP** | Modelado de programación lineal | Define variables $X_1, X_2, X_3, X_4$ y restricciones |
# | **NumPy** | Operaciones matemáticas vectorizadas | Facilita cálculos matriciales para análisis |
# | **Pandas** | Manipulación de datos tabulares | Organiza resultados de audiencia y costos |
# | **Matplotlib** | Visualización de datos | Grafica la distribución óptima de anuncios |
#
# El código implementa **manejo de errores** mediante bloques `try-except` para garantizar disponibilidad de herramientas, asegurando que el programa pueda ejecutarse correctamente y resolver la ecuación objetivo:
#
# $$\text{Maximizar } 5000X_1 + 8500X_2 + 2400X_3 + 2800X_4$$
#
# 🔍 Este paso es fundamental pues establece la infraestructura para modelar matemáticamente el problema de mezcla de medios.

# %%
"""
SOLUCIÓN DEL PROBLEMA DE MEZCLA DE MEDIOS PUBLICITARIOS
--------------------------------------------------------
Este script resuelve el problema de programación lineal del Club de Juegos "Win Big"
para maximizar el alcance de su audiencia distribuyendo un presupuesto de $8,000
entre diferentes medios publicitarios.

CONCEPTOS DE INVESTIGACIÓN DE OPERACIONES:
- Programación Lineal: Técnica matemática para optimizar una función objetivo sujeta
  a restricciones lineales.
- Función Objetivo: La medida que queremos maximizar o minimizar (en este caso, audiencia alcanzada).
- Restricciones: Limitaciones que deben satisfacerse (presupuesto, cantidad máxima de anuncios, etc.).
- Variables de decisión: Las incógnitas cuyo valor queremos determinar (cantidad de anuncios de cada tipo).
"""

# PASO 1: IMPORTAR LAS BIBLIOTECAS NECESARIAS
# ----------------------------------------------
# En Python, utilizamos bibliotecas externas para funcionalidades específicas.
# Para problemas de programación lineal, usamos PuLP o scipy.optimize.
# PuLP es más intuitivo para formular problemas de programación lineal.

# Importamos PuLP, una biblioteca específica para programación lineal
try:
    import pulp
except ImportError:
    print("La biblioteca PuLP no está instalada.")
    print("Puede instalarla usando: pip install pulp")
    exit(1)

# Importamos numpy para operaciones con arrays y pandas para visualización de datos
try:
    import numpy as np
    import pandas as pd
    # Matplotlib para gráficos si decidimos visualizar la solución
    import matplotlib.pyplot as plt
except ImportError:
    print("Alguna de las bibliotecas necesarias no está instalada.")
    print("Puede instalarlas usando: pip install numpy pandas matplotlib")
    exit(1)

# %% [markdown]
# # 📊 Definición de Datos del Problema
#
# ## 🎯 Función Principal
#
# El **PASO 2** del script transforma los datos del ejercicio "Win Big" en estructuras de Python para su manipulación algorítmica:
#
# | 🔄 Estructura | 📋 Descripción | 📝 Ejemplo |
# |---------------|---------------|-----------|
# | 📺 `medios` | Lista de canales publicitarios | `['TV', 'Periódico', 'Radio_pico', 'Radio_tarde']` |
# | 👥 `audiencia` | Diccionario de alcance por medio | `'TV': 5000` |
# | 💰 `costo` | Diccionario de precio por anuncio | `'Periódico': 925` |
# | 🔢 `max_anuncios` | Límites semanales por medio | `'Radio_pico': 25` |
#
# También define las constantes:
# * 💵 Presupuesto total: $8,000
# * 📻 Presupuesto radio: $1,800
# * 📣 Mínimo spots radio: 5
#
# Estas estructuras preparan los datos para la función objetivo:
# $$ \text{Maximizar } 5000X_1 + 8500X_2 + 2400X_3 + 2800X_4 $$

# %%
# PASO 2: DEFINIR LOS DATOS DEL PROBLEMA
# ---------------------------------------
# Definimos los parámetros del problema en estructuras de datos de Python.
# Esto facilita la modificación de los datos si es necesario.

# Tipos de medios publicitarios
medios = ['TV', 'Periódico', 'Radio_pico', 'Radio_tarde']

# Datos de cada medio: audiencia alcanzada, costo y máximo de anuncios
audiencia = {
    'TV': 5000,         # Personas alcanzadas por un spot de TV
    'Periódico': 8500,  # Personas alcanzadas por un anuncio de periódico
    'Radio_pico': 2400, # Personas alcanzadas por un spot de radio en hora pico
    'Radio_tarde': 2800 # Personas alcanzadas por un spot de radio en la tarde
}

costo = {
    'TV': 800,         # Costo por spot de TV ($)
    'Periódico': 925,  # Costo por anuncio de periódico ($)
    'Radio_pico': 290, # Costo por spot de radio en hora pico ($)
    'Radio_tarde': 380 # Costo por spot de radio en la tarde ($)
}

max_anuncios = {
    'TV': 12,         # Máximo de spots de TV por semana
    'Periódico': 5,   # Máximo de anuncios de periódico por semana
    'Radio_pico': 25, # Máximo de spots de radio en hora pico por semana
    'Radio_tarde': 20 # Máximo de spots de radio en la tarde por semana
}

# Presupuesto total disponible por semana
presupuesto_total = 8000  # en dólares

# Presupuesto máximo para anuncios de radio
presupuesto_radio = 1800  # en dólares

# Mínimo de spots de radio requeridos
min_spots_radio = 5

# Función para visualizar la información de las variables
def visualizar_info(variable, nombre):
    print(f"📊 Información de la variable: {nombre}")
    print(f"🔍 Tipo de variable: {type(variable)}")
    print(f"📏 Longitud/Estructura: {len(variable) if hasattr(variable, '__len__') else 'N/A'}")
    print(f"📄 Contenido:")
    print(variable)
    print("="*25)

# Visualizar la información de cada variable
visualizar_info(medios, "medios")
visualizar_info(audiencia, "audiencia")
visualizar_info(costo, "costo")
visualizar_info(max_anuncios, "max_anuncios")
visualizar_info(presupuesto_total, "presupuesto_total")
visualizar_info(presupuesto_radio, "presupuesto_radio")
visualizar_info(min_spots_radio, "min_spots_radio")
# Out:
# 📊 Información de la variable: medios
# 🔍 Tipo de variable: <class 'list'>
# 📏 Longitud/Estructura: 4
# 📄 Contenido:
# ['TV', 'Periódico', 'Radio_pico', 'Radio_tarde']
# ...
# 📊 Información de la variable: audiencia
# 🔍 Tipo de variable: <class 'dict'>
# 📏 Longitud/Estructura: 4
# 📄 Contenido:
# {'TV': 5000, 'Periódico': 8500, 'Radio_pico': 2400, 'Radio_tarde': 2800}
# ...
# 📊 Información de la variable: costo
# 🔍 Tipo de variable: <class 'dict'>
# 📏 Longitud/Estructura: 4
# 📄 Contenido:
# {'TV': 800, 'Periódico': 925, 'Radio_pico': 290, 'Radio_tarde': 380}
# ...
# 📊 Información de la variable: max_anuncios
# 🔍 Tipo de variable: <class 'dict'>
# 📏 Longitud/Estructura: 4
# 📄 Contenido:
# {'TV': 12, 'Periódico': 5, 'Radio_pico': 25, 'Radio_tarde': 20}
# ...
# 📊 Información de la variable: presupuesto_total
# 🔍 Tipo de variable: <class 'int'>
# 📏 Longitud/Estructura: N/A
# 📄 Contenido:
# 8000
# ...
# 📊 Información de la variable: presupuesto_radio
# 🔍 Tipo de variable: <class 'int'>
# 📏 Longitud/Estructura: N/A
# ...

# %% [markdown]
# # 🧩 Explicación del PASO 3: Modelo de Programación Lineal
#
# ## 🎯 Función Principal
#
# El PASO 3 establece la **estructura fundamental** del problema de optimización para "Win Big":
#
# | 🛠️ Componente | 📝 Descripción | 🧮 Implementación |
# |---------------|----------------|-------------------|
# | 📊 **Tipo de problema** | Maximización de audiencia | `pulp.LpProblem(sense=pulp.LpMaximize)` |
# | 🔢 **Variables de decisión** | Cantidad de anuncios ($X_1, X_2, X_3, X_4$) | `x = pulp.LpVariable.dicts("anuncios", medios, lowBound=0, cat=pulp.LpInteger)` |
#
# Este paso traduce la formulación matemática en código ejecutable, creando el contenedor para la función objetivo $Z = 5000X_1 + 8500X_2 + 2400X_3 + 2800X_4$ y las restricciones que serán definidas posteriormente.
#
# 💡 Las variables se definen como enteras y no negativas, reflejando que no podemos comprar fracciones de anuncios ni cantidades negativas.

# %%
# PASO 3: CREAR EL MODELO DE PROGRAMACIÓN LINEAL
# ----------------------------------------------
# Aquí creamos el modelo de PuLP y definimos las variables de decisión,
# la función objetivo y las restricciones.

# Crear un problema de maximización
# En programación lineal, podemos maximizar o minimizar una función objetivo
problema = pulp.LpProblem(name="Maximizacion_Audiencia", sense=pulp.LpMaximize)

# Definir las variables de decisión
# LpVariable.dicts crea un diccionario de variables, una para cada medio
# Las variables son no negativas (lowBound=0) y enteras (cat='Integer')
x = pulp.LpVariable.dicts("anuncios", medios, lowBound=0, cat=pulp.LpInteger)

visualizar_info(problema, "problema")
visualizar_info(x, "x")
# Out:
# 📊 Información de la variable: problema
# 🔍 Tipo de variable: <class 'pulp.pulp.LpProblem'>
# 📏 Longitud/Estructura: N/A
# 📄 Contenido:
# Maximizacion_Audiencia:
# MAXIMIZE
# None
# VARIABLES
#
# ...
# 📊 Información de la variable: x
# 🔍 Tipo de variable: <class 'dict'>
# 📏 Longitud/Estructura: 4
# 📄 Contenido:
# {'TV': anuncios_TV, 'Periódico': anuncios_Periódico, 'Radio_pico': anuncios_Radio_pico, 'Radio_tarde': anuncios_Radio_tarde}
# ...

# %% [markdown]
# # 🎯 PASO 4: Definición de la Función Objetivo
#
# ## 📊 Propósito
# El PASO 4 establece la **función objetivo** para maximizar el alcance total de audiencia del Club de Juegos "Win Big".
#
# ## 🧮 Fórmula Matemática
# $$ \text{Maximizar} \sum_{m \in \text{medios}} \text{audiencia}[m] \cdot x[m] = 5000 X_1 + 8500 X_2 + 2400 X_3 + 2800 X_4 $$
#
# ## 💻 Implementación
# ```python
# problema += pulp.lpSum([audiencia[m] * x[m] for m in medios]), "Audiencia_Total"
# ```
#
# ## 📝 Explicación Técnica
#
# | 🔍 Componente | ✨ Función |
# |--------------|-----------|
# | `pulp.lpSum()` | 🔢 Suma los productos de audiencia alcanzada por anuncios |
# | `[audiencia[m] * x[m] for m in medios]` | 🔄 List comprehension que multiplica cada coeficiente de audiencia por su variable |
# | `"Audiencia_Total"` | 🏷️ Etiqueta que identifica la función objetivo |
#
# 🚀 Esta línea traduce el objetivo matemático a código ejecutable, permitiendo al solucionador buscar valores óptimos para las variables de decisión.

# %%
# PASO 4: DEFINIR LA FUNCIÓN OBJETIVO
# -----------------------------------
# La función objetivo es maximizar la audiencia alcanzada
# Expresión: 5000*X_1 + 8500*X_2 + 2400*X_3 + 2800*X_4

# Crear la función objetivo sumando la audiencia alcanzada por cada medio
problema += pulp.lpSum([audiencia[m] * x[m] for m in medios]), "Audiencia_Total"
visualizar_info(problema, "problema")
# Out:
# 📊 Información de la variable: problema
# 🔍 Tipo de variable: <class 'pulp.pulp.LpProblem'>
# 📏 Longitud/Estructura: N/A
# 📄 Contenido:
# Maximizacion_Audiencia:
# MAXIMIZE
# 8500*anuncios_Periódico + 2400*anuncios_Radio_pico + 2800*anuncios_Radio_tarde + 5000*anuncios_TV + 0.0
# VARIABLES
# 0 <= anuncios_Periódico Integer
# 0 <= anuncios_Radio_pico Integer
# 0 <= anuncios_Radio_tarde Integer
# 0 <= anuncios_TV Integer
#
# ...

# %% [markdown]
# # 📊 PASO 5: IMPLEMENTACIÓN DE RESTRICCIONES
#
# ## 🔒 Función en el Modelo de Programación Lineal
#
# El **PASO 5** traduce matemáticamente las limitaciones del problema "Win Big" al lenguaje de programación:
#
# | 🔢 | ⚠️ Restricción | 🧮 Fórmula Matemática | 💻 Implementación Python |
# |-----|---------------|----------------------|--------------------------|
# | a | 📺 Máximo spots TV | $X_1 \leq 12$ | `x['TV'] <= max_anuncios['TV']` |
# | b | 📰 Máximo anuncios periódico | $X_2 \leq 5$ | `x['Periódico'] <= max_anuncios['Periódico']` |
# | c | 📻 Máximo spots radio (pico) | $X_3 \leq 25$ | `x['Radio_pico'] <= max_anuncios['Radio_pico']` |
# | d | 🎙️ Máximo spots radio (tarde) | $X_4 \leq 20$ | `x['Radio_tarde'] <= max_anuncios['Radio_tarde']` |
# | e | 💰 Presupuesto total | $800X_1 + 925X_2 + 290X_3 + 380X_4 \leq 8000$ | `pulp.lpSum([costo[m] * x[m] for m in medios]) <= presupuesto_total` |
# | f | 🔄 Mínimo spots radio | $X_3 + X_4 \geq 5$ | `x['Radio_pico'] + x['Radio_tarde'] >= min_spots_radio` |
# | g | 💸 Límite gasto radio | $290X_3 + 380X_4 \leq 1800$ | `costo['Radio_pico']*x['Radio_pico'] + costo['Radio_tarde']*x['Radio_tarde'] <= presupuesto_radio` |
#
# Este código 🔍 define el **espacio factible** donde el algoritmo buscará la solución óptima para maximizar el alcance de audiencia.

# %%
# PASO 5: AÑADIR LAS RESTRICCIONES
# --------------------------------
# Añadimos todas las restricciones del problema al modelo

# Restricción (a): Máximo de spots de TV por semana
problema += x['TV'] <= max_anuncios['TV'], "Max_TV"

# Restricción (b): Máximo de anuncios de periódico por semana
problema += x['Periódico'] <= max_anuncios['Periódico'], "Max_Periodico"

# Restricción (c): Máximo de spots de radio en hora pico por semana
problema += x['Radio_pico'] <= max_anuncios['Radio_pico'], "Max_Radio_Pico"

# Restricción (d): Máximo de spots de radio en la tarde por semana
problema += x['Radio_tarde'] <= max_anuncios['Radio_tarde'], "Max_Radio_Tarde"

# Restricción (e): Presupuesto total no puede exceder $8000
problema += pulp.lpSum([costo[m] * x[m] for m in medios]) <= presupuesto_total, "Presupuesto_Total"

# Restricción (f): Al menos 5 anuncios de radio por semana
problema += x['Radio_pico'] + x['Radio_tarde'] >= min_spots_radio, "Min_Anuncios_Radio"

# Restricción (g): Presupuesto en anuncios de radio no puede exceder $1800
problema += costo['Radio_pico']*x['Radio_pico'] + costo['Radio_tarde']*x['Radio_tarde'] <= presupuesto_radio, "Presupuesto_Radio"

visualizar_info(problema, "problema")
# Out:
# 📊 Información de la variable: problema
# 🔍 Tipo de variable: <class 'pulp.pulp.LpProblem'>
# 📏 Longitud/Estructura: N/A
# 📄 Contenido:
# Maximizacion_Audiencia:
# MAXIMIZE
# 8500*anuncios_Periódico + 2400*anuncios_Radio_pico + 2800*anuncios_Radio_tarde + 5000*anuncios_TV + 0.0
# SUBJECT TO
# Max_TV: anuncios_TV <= 12
#
# Max_Periodico: anuncios_Periódico <= 5
#
# Max_Radio_Pico: anuncios_Radio_pico <= 25
#
# Max_Radio_Tarde: anuncios_Radio_tarde <= 20
#
# Presupuesto_Total: 925 anuncios_Periódico + 290 anuncios_Radio_pico
#  + 380 anuncios_Radio_tarde + 800 anuncios_TV <= 8000
#
# Min_Anuncios_Radio: anuncios_Radio_pico + anuncios_Radio_tarde >= 5
#
# Presupuesto_Radio: 290 anuncios_Radio_pico + 380 anuncios_Radio_tarde <= 1800
#
# VARIABLES
# 0 <= anuncios_Periódico Integer
# 0 <= anuncios_Radio_pico Integer
# 0 <= anuncios_Radio_tarde Integer
# 0 <= anuncios_TV Integer
#
# ...

# %% [markdown]
# # 🚀 PASO 6: RESOLVER EL MODELO
#
# ## 🎯 Función Principal
#
# El **PASO 6** es el punto crucial donde el algoritmo de optimización encuentra la distribución óptima de anuncios para el Club "Win Big".
#
# | 📊 Componente | 🔍 Descripción |
# |--------------|---------------|
# | `problema.solve()` | 🧮 Ejecuta el algoritmo simplex para encontrar valores de $X_1$, $X_2$, $X_3$ y $X_4$ que maximicen $Z = 5000X_1 + 8500X_2 + 2400X_3 + 2800X_4$ |
# | `pulp.LpStatus[problema.status]` | ✅ Verifica si se encontró una solución óptima o si hubo algún error |
#
# ## 💡 Resultado
#
# Cuando finaliza, el modelo determina **exactamente cuántos anuncios** de cada medio maximizan la audiencia total respetando:
#
# $$\begin{cases}
# X_1 \leq 12 \\
# X_2 \leq 5 \\
# X_3 \leq 25 \\
# X_4 \leq 20 \\
# 800X_1 + 925X_2 + 290X_3 + 380X_4 \leq 8000 \\
# X_3 + X_4 \geq 5 \\
# 290X_3 + 380X_4 \leq 1800
# \end{cases}$$
#
# 🔄 Este paso transforma la teoría en acción, materializando la solución del problema de programación lineal.

# %%
# PASO 6: RESOLVER EL MODELO
# --------------------------
# Utilizamos el solucionador para encontrar la solución óptima

# Resolver el problema
problema.solve()

# Verificar el estado de la solución
# pulp.LpStatus[problema.status] devolverá 'Optimal' si se encuentra una solución óptima
print(f"\nEstado de la solución: {pulp.LpStatus[problema.status]}")
# Out:
# Estado de la solución: Optimal

# %% [markdown]
# # 🔍 Función del PASO 7: Mostrar Resultados
#
# ## 📊 Descripción General
#
# El **PASO 7** procesa y presenta la solución óptima del problema de programación lineal para el Club de Juegos "Win Big".
#
# ## 🧮 Operaciones Principales
#
# | Operación | Descripción | Fórmula |
# |-----------|-------------|---------|
# | 📈 Extracción de valores | Obtiene valores óptimos de variables | `valor = int(x[m].value())` |
# | 🔢 Cálculo de audiencia | Suma la audiencia alcanzada | $\sum_{m \in medios} audiencia_m \times X_m$ |
# | 💰 Cálculo de costo | Suma el costo total | $\sum_{m \in medios} costo_m \times X_m$ |
# | ⚖️ Cálculo de eficiencia | Determina costo por persona | $\frac{costo\_total}{audiencia\_total}$ |
# | ✅ Verificación | Comprueba restricciones especiales | $X_3 + X_4 \geq 5$ |
#
# ## 🎯 Importancia
#
# Este bloque es **crucial** ya que transforma los resultados matemáticos en información accionable para la toma de decisiones publicitarias, verificando el cumplimiento de todas las restricciones contractuales del modelo original.

# %%
# PASO 7: MOSTRAR LOS RESULTADOS
# -----------------------------
# Extraemos y mostramos los resultados de la solución

if problema.status == pulp.LpStatusOptimal:
    # Mostrar la solución óptima
    print("\nSOLUCIÓN ÓPTIMA:")
    print("--------------")
    
    # Crear un diccionario para almacenar los valores óptimos
    solucion = {}
    audiencia_total = 0
    costo_total = 0
    
    # Obtener los valores de las variables de decisión
    for m in medios:
        valor = int(x[m].value())  # Convertir a entero para evitar valores como 5.0
        solucion[m] = valor
        audiencia_total += audiencia[m] * valor
        costo_total += costo[m] * valor
        print(f"Número de anuncios en {m}: {valor}")
    
    # Mostrar el total de audiencia alcanzada y costo
    print(f"\nAudiencia total alcanzada: {audiencia_total} personas")
    print(f"Costo total: ${costo_total}")
    
    # Calcular el costo por persona alcanzada (eficiencia)
    if audiencia_total > 0:
        costo_por_persona = costo_total / audiencia_total
        print(f"Costo por persona alcanzada: ${costo_por_persona:.4f}")
    
    # Verificar el cumplimiento de restricciones especiales
    total_radio = solucion['Radio_pico'] + solucion['Radio_tarde']
    costo_radio = costo['Radio_pico']*solucion['Radio_pico'] + costo['Radio_tarde']*solucion['Radio_tarde']
    
    print(f"\nVerificación de restricciones especiales:")
    print(f"- Total de anuncios de radio: {total_radio} (mínimo requerido: {min_spots_radio})")
    print(f"- Costo total en radio: ${costo_radio} (máximo permitido: ${presupuesto_radio})")
# Out:
# SOLUCIÓN ÓPTIMA:
# --------------
# Número de anuncios en TV: 2
# Número de anuncios en Periódico: 5
# Número de anuncios en Radio_pico: 6
# Número de anuncios en Radio_tarde: 0
#
# Audiencia total alcanzada: 66900 personas
# Costo total: $7965
# Costo por persona alcanzada: $0.1191
#
# Verificación de restricciones especiales:
# - Total de anuncios de radio: 6 (mínimo requerido: 5)
# - Costo total en radio: $1740 (máximo permitido: $1800)

# %% [markdown]
# # 📊 Visualización de Resultados en la Optimización de Medios
#
# ## 🔍 Función del PASO 8
#
# El PASO 8 transforma los datos numéricos en representación visual para facilitar la interpretación de la solución óptima del problema publicitario de "Win Big".
#
# ### 📋 Organización de Datos
#
# ```python
# df_resultados = pd.DataFrame({...})
# ```
#
# Crea una estructura tabular con los siguientes datos:
#
# | 📱 Medio | 🔢 Cantidad | 👥 Audiencia | 💰 Costo |
# |---------|------------|-------------|---------|
# | TV      | $X_1$      | $5000X_1$   | $800X_1$|
# | Periódico| $X_2$     | $8500X_2$   | $925X_2$|
# | Radio_pico| $X_3$    | $2400X_3$   | $290X_3$|
# | Radio_tarde| $X_4$   | $2800X_4$   | $380X_4$|
#
# ### 📈 Generación de Gráfico
#
# Crea un gráfico de barras que muestra la distribución óptima de anuncios por medio, permitiendo:
#
# - 👁️ Visualizar la asignación de recursos
# - 🔄 Comparar fácilmente entre medios
# - 💡 Identificar patrones en la solución
# - 📝 Documentar resultados mediante imagen guardada
#
# Esta representación visual complementa el análisis numérico y facilita la toma de decisiones estratégicas para maximizar el alcance publicitario.

# %%
# PASO 8: VISUALIZACIÓN DE RESULTADOS (OPCIONAL)
# ---------------------------------------------
# Creamos un gráfico de barras para visualizar la distribución de anuncios

# Crear un DataFrame para facilitar la visualización
df_resultados = pd.DataFrame({
    'Medio': medios,
    'Cantidad': [solucion[m] for m in medios],
    'Audiencia': [audiencia[m] * solucion[m] for m in medios],
    'Costo': [costo[m] * solucion[m] for m in medios]
})

print("\nTabla de resultados:")
print(df_resultados)

# Crear el gráfico de barras para la cantidad de anuncios
plt.figure(figsize=(10, 6))
plt.bar(medios, [solucion[m] for m in medios])
plt.xlabel('Medio')
plt.ylabel('Cantidad de anuncios')
plt.title('Distribución óptima de anuncios por medio')
plt.xticks(rotation=45)

# Mostrar valores en las barras
for i, v in enumerate([solucion[m] for m in medios]):
    plt.text(i, v + 0.5, str(v), ha='center')

plt.tight_layout()
# plt.show()  # Descomenta esta línea si estás ejecutando el script en un entorno que puede mostrar gráficos

# Guardar el gráfico como imagen
plt.savefig('distribucion_anuncios.png')
print("\nGráfico guardado como 'distribucion_anuncios.png'")
# Out:
# Tabla de resultados:
#          Medio  Cantidad  Audiencia  Costo
# 0           TV         2      10000   1600
# 1    Periódico         5      42500   4625
# 2   Radio_pico         6      14400   1740
# 3  Radio_tarde         0          0      0
# Gráfico guardado como 'distribucion_anuncios.png'

# %% [markdown]
# # 📊 Función del Análisis de Sensibilidad en Programación Lineal
#
# ## 🔍 Descripción General
#
# El **Paso 9** del script implementa un **análisis de sensibilidad** para el problema de optimización publicitaria de "Win Big". Esta fase es crucial pues:
#
# | 🎯 Objetivo | 📝 Descripción |
# |-------------|---------------|
# | ⚖️ Estabilidad | Evalúa cuán robusta es la solución ante cambios en parámetros |
# | 💰 Valor marginal | Identifica el impacto de modificar restricciones presupuestarias |
# | 📈 Toma de decisiones | Proporciona información para decisiones estratégicas |
#
# ## 🧮 Conceptos Matemáticos Aplicados
#
# El análisis se basa en la **teoría de dualidad** donde:
#
# $$Z = \sum_{i=1}^{n} c_i x_i$$
#
# La solución dual proporciona **precios sombra** ($y_j$) que indican cuánto cambiaría la función objetivo si la restricción $j$ se relaja en una unidad:
#
# $$\Delta Z \approx y_j \cdot \Delta b_j$$
#
# ## 🚀 Recomendación Final
#
# El script concluye presentando la distribución óptima de anuncios y cuantificando la audiencia máxima alcanzable ($\sum_{i=1}^{n} a_i x_i$) con el presupuesto disponible, señalando cualquier recurso no utilizado.

# %%
# PASO 9: ANÁLISIS DE SENSIBILIDAD (OPCIONAL)
# -----------------------------------------
# El análisis de sensibilidad nos permite entender cómo cambios en los parámetros
# afectarían a la solución óptima.

print("\nANÁLISIS DE SENSIBILIDAD:")
print("----------------------")

# Obtener los valores duales (precios sombra) de las restricciones
# Nota: No todos los solucionadores proporcionan esta información directamente en PuLP

print("Nota: Para un análisis de sensibilidad completo, se recomienda utilizar")
print("herramientas más especializadas como CPLEX o Gurobi que proporcionan")
print("información detallada sobre variables duales y rangos de sensibilidad.")

# Impresión del informe final
print("\nRECOMENDACIÓN FINAL:")
print("-----------------")
print(f"Para maximizar la audiencia alcanzada ({audiencia_total} personas) con un presupuesto de ${presupuesto_total},")
print(f"el Club de Juegos 'Win Big' debería distribuir sus anuncios de la siguiente manera:")

for m in medios:
    print(f"- {solucion[m]} anuncios en {m}")

print(f"\nEsto tendría un costo total de ${costo_total}, dejando ${presupuesto_total - costo_total} sin utilizar.")

"""
CONCEPTOS ADICIONALES DE INVESTIGACIÓN DE OPERACIONES:
- Dualidad: Cada problema de programación lineal tiene un problema dual asociado que
  proporciona información sobre el valor marginal de los recursos.
- Análisis de sensibilidad: Estudia cómo los cambios en los parámetros afectan a la solución óptima.
- Precios sombra: Indican cuánto mejoraría la función objetivo si se relajara una restricción.

NOTAS SOBRE PYTHON:
- Las estructuras de datos como diccionarios (dict) y listas (list) son muy útiles
  para organizar datos en problemas de investigación de operaciones.
- Las bibliotecas especializadas como PuLP facilitan la formulación y resolución de
  problemas de optimización.
- La programación orientada a objetos en Python permite una organización clara del código.
- Los 'list comprehensions' [expresión for item in iterable] son una forma concisa
  de crear listas en Python.
"""
# Out:
# ANÁLISIS DE SENSIBILIDAD:
# ----------------------
# Nota: Para un análisis de sensibilidad completo, se recomienda utilizar
# herramientas más especializadas como CPLEX o Gurobi que proporcionan
# información detallada sobre variables duales y rangos de sensibilidad.
#
# RECOMENDACIÓN FINAL:
# -----------------
# Para maximizar la audiencia alcanzada (66900 personas) con un presupuesto de $8000,
# el Club de Juegos 'Win Big' debería distribuir sus anuncios de la siguiente manera:
# - 2 anuncios en TV
# - 5 anuncios en Periódico
# - 6 anuncios en Radio_pico
# - 0 anuncios en Radio_tarde
#
# Esto tendría un costo total de $7965, dejando $35 sin utilizar.
# ...
